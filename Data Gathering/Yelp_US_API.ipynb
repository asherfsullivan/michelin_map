# %%
import requests
import json
from config import api_key
import pandas as pd

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
cities = ['New York City','San Francisco','Chicago','Los Angeles','Washington DC','South San Francisco','San Diego','Monterey']

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

# %%
d=[]
for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
df1 = pd.DataFrame(d)
df1
# Out:
#                                   name  rating  review_count price  \
# 0                     Thursday Kitchen     4.5          1537    $$
# 1                       Joe's Shanghai     4.0          6637    $$
# 2                             LoveMama     4.5          5809    $$
# 3                             Rubirosa     4.5          2579    $$
# 4                            Da Andrea     4.5          1159    $$
# 5                        The Cabin NYC     4.0           402    $$
# 6                        Gelso & Grand     4.5          1179    $$
# 7                              Anytime     4.5          1928    $$
# 8           The Wild Son Lunch Counter     4.5           548    $$
# 9                      Jane Restaurant     4.0          3315    $$
# 10                  Sunday in Brooklyn     4.0          1033    $$
# 11                     Salt + Charcoal     4.0           628    $$
# 12                                Raku     4.5          1289    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 51}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

# %%
e=[]
for business in businesses:
    e.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
df2 = pd.DataFrame(e)
df2
# Out:
#                                    name  rating  review_count price  \
# 0             Tasty Hand-Pulled Noodles     4.0          1697    $$
# 1                           Fish Cheeks     4.5           965    $$
# 2                          Pig and Khao     4.0          1744   $$$
# 3                               Evelina     4.5           255   $$$
# 4                   DOMODOMO - New York     4.5          1336   $$$
# 5                            Ichibantei     4.0           247    $$
# 6            Paesano of Mulberry Street     4.0          1145    $$
# 7                       Her Name Is Han     4.5          1465    $$
# 8                                  Otis     5.0           408   $$$
# 9                                  Uluh     4.5           647   $$$
# 10             San Marzano Pasta Fresca     4.0          1345    $$
# 11                          Ruby's Cafe     4.5           234    $$
# 12                          La Contenta     4.5           821    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 101}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


f=[]
for business in businesses:
    f.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df3 = pd.DataFrame(f)
df3
# Out:
#                                name  rating  review_count price  \
# 0                      Pasta Louise     4.5           193    $$
# 1                            Supper     4.0          1396    $$
# 2                            Popina     4.5            77    $$
# 3                           Okonomi     4.5           474    $$
# 4                             FERNS     4.5           137    $$
# 5            ICHIRAN - Times Square     4.5           555    $$
# 6                          L'Artusi     4.5          2016   $$$
# 7                              Olea     4.0           941    $$
# 8            Boucherie Union Square     4.5          1065   $$$
# 9             Frankies 457 Spuntino     4.0           851   $$$
# 10                   The River Café     4.0          1189  $$$$
# 11                            Emily     4.0           855    $$
# 12                     Cafe Mogador     4.0          2000    $$
# 13                             Esme     4.5           363    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 151}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


g=[]
for business in businesses:
    g.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df4 = pd.DataFrame(g)
df4
# Out:
#                             name  rating  review_count price  \
# 0                      Ampersand     4.5           236    $$
# 1                      Roberta's     4.0          3068    $$
# 2                Cecconi's Dumbo     3.5           897   $$$
# 3                Jajaja Mexicana     4.5          1089    $$
# 4                           Peak     4.5           206  $$$$
# 5                      Bricolage     4.0           587   $$$
# 6              Hart's Restaurant     4.0            95   $$$
# 7               Good Thanks Cafe     4.5           280    $$
# 8      Marufuku Ramen - New York     4.5           100    $$
# 9                      Tara Rose     4.5           468    $$
# 10                    Chow House     4.5           494    $$
# 11                    Da Claudio     4.5           543    $$
# 12            Hometown Bar-B-Que     4.0          1488    $$
# 13                      The Binc     4.5            74    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 201}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


h=[]
for business in businesses:
    h.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df5 = pd.DataFrame(h)
df5
# Out:
#                                            name  rating  review_count price  \
# 0                                        Kiki's     4.0           707    $$
# 1                                    5ive Spice     4.5           803    $$
# 2                                        Upland     4.0          1106   $$$
# 3                                    Lighthouse     4.0           281    $$
# 4                                 City Vineyard     4.0          1042    $$
# 5                              La Pecora Bianca     4.0           820    $$
# 6                                  Saigon Shack     4.0          2537    $$
# 7                          Emily - West Village     4.0           822    $$
# 8                                     Llama Inn     4.0           585   $$$
# 9                          Sunflower - Gramercy     4.5           223    $$
# 10                                        Leuca     4.0           371   $$$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 251}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


i=[]
for business in businesses:
    i.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df6 = pd.DataFrame(i)
df6
# Out:
#                                name  rating  review_count price  \
# 0                              Misi     4.0           426   $$$
# 1              Chela Modern Mexican     4.5           574    $$
# 2                        Fresh Salt     4.0           409    $$
# 3                         The Smith     4.0          1170   $$$
# 4                     Silky Kitchen     4.5           255    $$
# 5                    Yakitori Totto     4.0          1371   $$$
# 6                           Mr. Sun     4.5            99    $$
# 7                   Gramercy Tavern     4.5          3059  $$$$
# 8                              Soco     4.0          2252    $$
# 9                     Awesum Dimsum     4.5           292    $$
# 10                   Three Roosters     4.5           136    $$
# 11            Sweetwater Restaurant     4.0           427    $$
# 12                    Locanda Verde     4.0          1728   $$$
# 13            The Orchard Townhouse     4.0            55   $$$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 301}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


j=[]
for business in businesses:
    j.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df7 = pd.DataFrame(j)
df7
# Out:
#                              name  rating  review_count price  \
# 0                         Mao Mao     4.0            47    $$
# 1                 ICHIRAN Midtown     4.0          1015    $$
# 2                      Trapizzino     4.5           252    $$
# 3                        Kabisera     4.5           120    $$
# 4                Ume Williamsburg     4.0           314  $$$$
# 5     The Grey Dog - Union Square     4.0          1110    $$
# 6                         Fornino     4.0           268    $$
# 7                      Katsu-Hama     4.0          1443    $$
# 8      YunShang Rice Noodle House     4.0           247    $$
# 9                  Joseph Leonard     4.0           689    $$
# 10                    Mekelburg's     4.0            86    $$
# 11                 Vineapple Cafe     4.5            81    $$
# 12                       The Wren     4.0           582    $$
# 13                      Llama San     4.0           214  $$$$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 351}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


k=[]
for business in businesses:
    k.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df8 = pd.DataFrame(k)
df8
# Out:
#                            name  rating  review_count price  \
# 0                         Otway     4.0            94   $$$
# 1           Ootoya Union Square     4.0           359    $$
# 2            Hao Noodle Chelsea     4.5           488    $$
# 3         Lillo Cucina Italiana     5.0           174    $$
# 4                  Elder Greene     4.0            62    $$
# 5                      Cookshop     4.0          2183    $$
# 6                   Peter Luger     4.0          6196  $$$$
# 7   Cuba Restaurant and Rum Bar     4.0          1615    $$
# 8                        Fausto     4.0           187   $$$
# 9                     Coarse NY     4.5           286   $$$
# 10                     Mayfield     4.0           565    $$
# 11  Judge Roy Bean Public House     4.5           785    $$
# 12                   Friedman's     4.0           703    $$
# 13                         JoJo     4.0           194   $$$
# 14                        Juban     4.0           214    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 401}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


l=[]
for business in businesses:
    l.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df9 = pd.DataFrame(l)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 451}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df10 = pd.DataFrame(m)

# %%
NY_yelp_df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10],ignore_index=True)

# %%
NY_yelp_df
# Out:
#                  name  rating  review_count price  \
# 0    Thursday Kitchen     4.5          1537    $$
# 1      Joe's Shanghai     4.0          6637    $$
# 2            LoveMama     4.5          5809    $$
# 3            Rubirosa     4.5          2579    $$
# 4           Da Andrea     4.5          1159    $$
# ..                ...     ...           ...   ...
# 495      Bohemien Bar     4.0            32    $$
# 496       Le Pavillon     4.0            81  $$$$
# 497    12 Chairs Cafe     4.0           364    $$
# 498   Petisco Brazuca     4.5            60    $$
# 499     Cena Brooklyn     4.0           116    $$
#
#                                             categories      city state  \
# 0    [{'alias': 'korean', 'title': 'Korean'}, {'ali...  New York    NY
# 1    [{'alias': 'shanghainese', 'title': 'Shanghain...  New York    NY
# 2    [{'alias': 'thai', 'title': 'Thai'}, {'alias':...  New York    NY
# 3    [{'alias': 'italian', 'title': 'Italian'}, {'a...  New York    NY
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 501}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df11 = pd.DataFrame(m)
df11
# Out:
#                                       name  rating  review_count price  \
# 0          Momosan Ramen & Sake - New York     4.0          1728    $$
# 1                                BLACKBARN     4.0           630   $$$
# 2                     Mercado Little Spain     3.5           436    $$
# 3                          Taste of Heaven     5.0           195    $$
# 4                              Maison Yaki     3.5           118   $$$
# 5                                 Coppelia     4.0          1411    $$
# 6                               Jongro BBQ     4.0          2224    $$
# 7                                 Bar Goto     4.5           245    $$
# 8          Loulou Petit Bistro & Speakeasy     4.0           334   $$$
# 9                         Baba's Pierogies     4.5           437    $$
# 10                             Sweet Chick     4.0          2124    $$
# 11                          The Dolar Shop     4.5           142   $$$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 551}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df12 = pd.DataFrame(m)
df12
# Out:
#                                   name  rating  review_count price  \
# 0                            Grindhaus     4.5           106    $$
# 1                         Little Alley     4.0           428    $$
# 2                         Latham House     4.0           476    $$
# 3                  Black Tap - Midtown     4.0          1255    $$
# 4                       Laut Singapura     4.0           268    $$
# 5                            Matsunori     4.5            25  $$$$
# 6                    The Bluebell Cafe     4.0           632    $$
# 7            Hao Noodle - West Village     4.0           791    $$
# 8                    La Contenta Oeste     4.0           275    $$
# 9                          Sally Roots     4.0           286    $$
# 10                         Basta Pasta     4.0          1488    $$
# 11                            SUteiShi     4.0           545   $$$
# 12                   Barely Disfigured     4.5           116    $$
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 601}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df13 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' :651}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df14 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 701}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df15 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 751}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df16 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 801}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df17 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 851}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df18 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':50, 'offset' : 901}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df19 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':49, 'offset' : 951}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df20 = pd.DataFrame(m)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'New York City','price':'2,3,4','limit':1, 'offset' : 50}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


m=[]
for business in businesses:
    m.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

df21 = pd.DataFrame(m)

# %%
NY_yelp_df = pd.concat([NY_yelp_df,df21,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20],ignore_index=True)

# %%
#NY_yelp_df

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/NY_yelp_data.csv')  
NY_yelp_df.to_csv(filepath,index=False)

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 0}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]


d=[]
for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 50}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 100}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 150}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 200}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 250}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 300}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 350}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 400}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 450}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 500}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 550}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 600}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 650}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 700}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 750}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 800}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 850}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 900}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
url = 'https://api.yelp.com/v3/businesses/search'

params = {'term':'restaurant','location':'San Francisco','price':'2,3,4','limit':50, 'offset' : 950}

req = requests.get(url, params=params, headers=headers)
 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

for business in businesses:
    d.append(
        {
            'name':business["name"],
            'rating':business["rating"],
            'review_count':business["review_count"],
            'price':business["price"],
            'categories':business["categories"],
            'city':business["location"]["city"],
            'state':business["location"]["state"],
            'zip_code':business["location"]["zip_code"],
            'latitude': business["coordinates"]["latitude"],
            'longitude':business["coordinates"]["longitude"],
            'address':" ".join(business["location"]["display_address"]),
            'url':business["url"]
        })

# %%
SF_yelp_df = pd.DataFrame(d)

# %%
SF_yelp_df
# Out:
#                                           name  rating  review_count price  \
# 0                               Marufuku Ramen     4.5          3685    $$
# 1               Farmhouse Kitchen Thai Cuisine     4.0          3085    $$
# 2                                    Parada 22     4.0          1328    $$
# 3                                Jamie's place     4.5           167    $$
# 4                                Kitchen Story     4.0          3675    $$
# ..                                         ...     ...           ...   ...
# 995  The Clubhouse at the Presidio Golf Course     4.5            73    $$
# 996                          Precita Park Cafe     3.5           455    $$
# 997                               Wang Dae Bak     3.5           317    $$
# 998                                   Blue Pea     4.0           140    $$
# 999                  Keith's Chicken N Waffles     4.5           821    $$
#
# ...

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/SF_yelp_data.csv')  
SF_yelp_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'Chicago','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
chicago_df = pd.DataFrame(z)

# %%
chicago_df
# Out:
#                               name  rating  review_count price  \
# 0                        The Perch     4.5           252    $$
# 1                  Girl & The Goat     4.5          9011   $$$
# 2                   The Purple Pig     4.0          7515   $$$
# 3                The Whale Chicago     4.0           657    $$
# 4                  etta - Bucktown     4.5           839    $$
# ..                             ...     ...           ...   ...
# 995  Chicken Works & Salad Company     4.0           251    $$
# 996                    Miss Saigon     4.5           186    $$
# 997       Dawali Jerusalem Kitchen     4.0           519    $$
# 998                     Formento's     4.0           647   $$$
# 999                Uncommon Ground     3.5          1122    $$
#
#                                             categories     city state  \
# 0    [{'alias': 'breweries', 'title': 'Breweries'},...  Chicago    IL
# ...

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/chicago_yelp_data.csv')  
chicago_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'Los Angeles','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
LA_yelp_df = pd.DataFrame(z)

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/la_yelp_data.csv')  
LA_yelp_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'Washington, DC','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
DC_yelp_df = pd.DataFrame(z)

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/dc_yelp_data.csv')  
DC_yelp_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'South San Francisco','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
SSF_yelp_df = pd.DataFrame(z)

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/ssf_yelp_data.csv')  
SSF_yelp_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'San Diego','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
SD_yelp_df = pd.DataFrame(z)

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/SD_yelp_data.csv')  
SD_yelp_df.to_csv(filepath,index=False)

# %%
z = []
offsets = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950]

# %%
url = 'https://api.yelp.com/v3/businesses/search'

for offset in offsets:

    params = {'term':'restaurant','location':'Monterey','price':'2,3,4','limit':50, 'offset' : offset }

    req = requests.get(url, params=params, headers=headers)

    parsed = json.loads(req.text)
    businesses = parsed["businesses"]

    for business in businesses:
        z.append(
            {
                'name':business["name"],
                'rating':business["rating"],
                'review_count':business["review_count"],
                'price':business["price"],
                'categories':business["categories"],
                'city':business["location"]["city"],
                'state':business["location"]["state"],
                'zip_code':business["location"]["zip_code"],
                'latitude': business["coordinates"]["latitude"],
                'longitude':business["coordinates"]["longitude"],
                'address':" ".join(business["location"]["display_address"]),
                'url':business["url"]
            })

# %%
Mon_yelp_df = pd.DataFrame(z)

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/M_yelp_data.csv')  
Mon_yelp_df.to_csv(filepath,index=False)

# %%
# combine the data into a single dataset
yelp_df = pd.concat([NY_yelp_df,SF_yelp_df,chicago_df,LA_yelp_df,DC_yelp_df,SSF_yelp_df,SD_yelp_df,Mon_yelp_df],ignore_index=True)

# %%
yelp_df
# Out:
#                                    name  rating  review_count price  \
# 0                      Thursday Kitchen     4.5          1537    $$
# 1                        Joe's Shanghai     4.0          6637    $$
# 2                              LoveMama     4.5          5809    $$
# 3                              Rubirosa     4.5          2579    $$
# 4                             Da Andrea     4.5          1159    $$
# ...                                 ...     ...           ...   ...
# 6927                       Bushwacker's     1.5             4    $$
# 6928              Mountain Mike's Pizza     2.5            97    $$
# 6929                  Round Table Pizza     2.0           120    $$
# 6930         Latino Market and Taqueria     4.0             4    $$
# 6931  Steinbeck's Deli and Espresso Bar     2.0             3    $$
#
#                                              categories      city state  \
# 0     [{'alias': 'korean', 'title': 'Korean'}, {'ali...  New York    NY
# ...

# %%
# save df as csv and save to Resources folder 
from pathlib import Path 
filepath = Path('./Resources/yelp_data.csv')  
yelp_df.to_csv(filepath,index=False)

# %%
filepath = Path('./Resources/yelp_data.csv')
df = pd.read_csv(filepath)

# %%
#insert data into a database
import sqlite3
connection = sqlite3.connect(':memory:')

df.to_sql(name='non_michelin_yelp_data', con=connection)

# %%
df1 = pd.read_sql('select * from non_michelin_yelp_data', connection)
#df1.head()
